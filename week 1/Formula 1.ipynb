# %%
pwd
# Out:
# 'D:\\Users\\VARUN\\Desktop\\Python'

# %%
import pandas as pd

# %%
circuits_dataset=pd.read_csv("circuits.csv")

# %%
circuits_dataset
# Out:
#      circuit_reference                          circuit_name circuit_location  \
# 0          albert_park        Albert Park Grand Prix Circuit        Melbourne
# 1          albert_park        Albert Park Grand Prix Circuit        Melbourne
# 2          albert_park        Albert Park Grand Prix Circuit        Melbourne
# 3          albert_park        Albert Park Grand Prix Circuit        Melbourne
# 4          albert_park        Albert Park Grand Prix Circuit        Melbourne
# ...                ...                                   ...              ...
# 1074           mugello  Autodromo Internazionale del Mugello          Mugello
# 1075            jeddah               Jeddah Corniche Circuit           Jeddah
# 1076            jeddah               Jeddah Corniche Circuit           Jeddah
# 1077            losail          Losail International Circuit        Al Daayen
# 1078             miami         Miami International Autodrome            Miami
#
# ...
